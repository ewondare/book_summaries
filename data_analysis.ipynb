# %% [markdown]
# ## 1.Data Preprocessing and EDA:

# %% [markdown]
# ### 1.1. data cleaning and handling missing values

# %% [markdown]
# #### 1.1.1. reading data into a dataframe format

# %%
import pandas as pd
df = pd.read_csv('booksummaries.txt' , sep='\t' , header=None)

df.head()
# Out:
#       0        1                                          2                3  \
# 0   620  /m/0hhy                                Animal Farm    George Orwell
# 1   843  /m/0k36                         A Clockwork Orange  Anthony Burgess
# 2   986  /m/0ldx                                 The Plague     Albert Camus
# 3  1756  /m/0sww  An Enquiry Concerning Human Understanding       David Hume
# 4  2080  /m/0wkt                       A Fire Upon the Deep     Vernor Vinge
#
#             4                                                  5  \
# 0  1945-08-17  {"/m/016lj8": "Roman \u00e0 clef", "/m/06nbt":...
# 1        1962  {"/m/06n90": "Science Fiction", "/m/0l67h": "N...
# 2        1947  {"/m/02m4t": "Existentialism", "/m/02xlf": "Fi...
# 3         NaN                                                NaN
# 4         NaN  {"/m/03lrw": "Hard science fiction", "/m/06n90...
#
#                                                    6
# 0   Old Major, the old boar on the Manor Farm, ca...
# 1   Alex, a teenager living in near-future Englan...
# 2   The text of The Plague is divided into five p...
# 3   The argument of the Enquiry proceeds by a ser...
# 4   The novel posits that space around the Milky ...

# %% [markdown]
# #### 1.1.2. renaming the columns, editing columns type

# %%
df.rename(columns={0:'id' , 2:'name' , 3:'author' , 4:'publish_year' , 6:'summary'} , inplace=True)

# %%
#df = df.drop(columns=[1 , 5] , axis=1)
df.rename(columns={1:'txt' , 5:'genre'} , inplace=True)

# %%
df['publish_year'] = df['publish_year'].str[:4]

# %%
df.head()
# Out:
#      id      txt                                       name           author  \
# 0   620  /m/0hhy                                Animal Farm    George Orwell
# 1   843  /m/0k36                         A Clockwork Orange  Anthony Burgess
# 2   986  /m/0ldx                                 The Plague     Albert Camus
# 3  1756  /m/0sww  An Enquiry Concerning Human Understanding       David Hume
# 4  2080  /m/0wkt                       A Fire Upon the Deep     Vernor Vinge
#
#   publish_year                                              genre  \
# 0         1945  {"/m/016lj8": "Roman \u00e0 clef", "/m/06nbt":...
# 1         1962  {"/m/06n90": "Science Fiction", "/m/0l67h": "N...
# 2         1947  {"/m/02m4t": "Existentialism", "/m/02xlf": "Fi...
# 3          NaN                                                NaN
# 4          NaN  {"/m/03lrw": "Hard science fiction", "/m/06n90...
#
#                                              summary
# 0   Old Major, the old boar on the Manor Farm, ca...
# 1   Alex, a teenager living in near-future Englan...
# 2   The text of The Plague is divided into five p...
# 3   The argument of the Enquiry proceeds by a ser...
# 4   The novel posits that space around the Milky ...

# %%
df.dtypes
# Out:
# id               int64
# txt             object
# name            object
# author          object
# publish_year    object
# genre           object
# summary         object
# dtype: object

# %%
import ast

df['genre'] = df['genre'].str.replace('u00e0', '', regex=False)

def extract_genres(genre_str):
    if isinstance(genre_str, str):  # Check if the input is a string
        genre_dict = ast.literal_eval(genre_str.replace('\\', ''))
        return list(genre_dict.values())
    return []  # Return an empty list for NaN or non-string values


df['genre_names'] = df['genre'].apply(extract_genres)
df = df.drop(columns=['txt', 'genre'])

# %%
df.shape
# Out:
# (16559, 6)

# %% [markdown]
# #### 1.1.1.3 handling missing values: publish year , genres , author

# %%
import numpy as np
df['genre_names'] = df['genre_names'].apply(lambda x: np.nan if len(x) == 0 else x)

# %%
print(df.isna().sum())
# Out:
# id                 0
# name               0
# author          2382
# publish_year    5610
# summary            0
# genre_names     3718
# dtype: int64

# %%
for index in df[df['name'].str.match(r'^Book of')].index:
    df.at[index, 'genre_names'] = ['Religious text']

# %%
for index in df[df['name'].str.match(r'^Book of')].index:
    df.at[index, 'publish_year'] = 0

# %%
for index in df[df['name'].str.match(r'^Book of')].index:
    # Extract the name after 'Book of'
    x = df.at[index, 'name'].replace('Book of ', '')
    df.at[index, 'author'] = x

# %%
df.loc[
    (df['genre_names'].apply(lambda x: x == ['Religious text'])) & 
    (df['author'].isna()) & 
    (df['publish_year'].isna()), 
    'publish_year'
] = 0

# %%
filtered_df = df[df['genre_names'].apply(lambda x: x == ['Religious text'])]
filtered_df
# Out:
#              id                     name           author publish_year  \
# 10         4331           Book of Joshua           Joshua            0
# 11         4332             Book of Ezra             Ezra            0
# 12         4376          Book of Numbers          Numbers            0
# 13         4381             Book of Ruth             Ruth            0
# 14         4382           Book of Esther           Esther            0
# 15         4386              Book of Job              Job            0
# 16         4449            Book of Hosea            Hosea            0
# 17         4451            Book of Jonah            Jonah            0
# 18         4452            Book of Micah            Micah            0
# 19         4454           Book of Haggai           Haggai            0
# 32         9662                   Exodus              NaN            0
# 40        12667                  Genesis              NaN            0
# 5158    3989801         Book of the Dead         the Dead            0
# 10279  12186451  Book of a Thousand Days  a Thousand Days            0
# 13199  20195316   Book of the Black Bass   the Black Bass            0
#
#                                                  summary       genre_names
# 10      (Chapter 1 is the first of three important mo...  [Religious text]
# 11      For the Bible text, see Bible Gateway (opens ...  [Religious text]
# 12      God orders Moses, in the wilderness of Sinai,...  [Religious text]
# 13      During the time of the Judges when there was ...  [Religious text]
# 14      Ahasuerus, ruler of a massive Persian empire,...  [Religious text]
# 15      The book of Job tells the story of an extreme...  [Religious text]
# 16      First, Hosea was directed by God to marry a p...  [Religious text]
# 17      The plot centers on a conflict between Jonah ...  [Religious text]
# 18      * The Heading (1:1): As is typical of prophet...  [Religious text]
# 19      Haggai's message is filled with an urgency fo...  [Religious text]
# 32      Egypt's Pharaoh, fearful of the Israelites' n...  [Religious text]
# 40      God creates the world in six days and consecr...  [Religious text]
# 5158    Wes has loved books since childhood. When a f...  [Religious text]
# 10279   When Dashti, a mucker from the steppes of Tit...  [Religious text]
# 13199   Henshall's Book of Black Bass is really three...  [Religious text]

# %%
df.head(30)
# Out:
#       id                                       name                author  \
# 0    620                                Animal Farm         George Orwell
# 1    843                         A Clockwork Orange       Anthony Burgess
# 2    986                                 The Plague          Albert Camus
# 3   1756  An Enquiry Concerning Human Understanding            David Hume
# 4   2080                       A Fire Upon the Deep          Vernor Vinge
# 5   2152             All Quiet on the Western Front  Erich Maria Remarque
# 6   2890                       A Wizard of Earthsea     Ursula K. Le Guin
# 7   2950                         Anyone Can Whistle       Arthur Laurents
# 8   4081            Blade Runner 3: Replicant Night           K. W. Jeter
# 9   4082          Blade Runner 2: The Edge of Human           K. W. Jeter
# 10  4331                             Book of Joshua                Joshua
# 11  4332                               Book of Ezra                  Ezra
# 12  4376                            Book of Numbers               Numbers
# 13  4381                               Book of Ruth                  Ruth
# 14  4382                             Book of Esther                Esther
# 15  4386                                Book of Job                   Job
# 16  4449                              Book of Hosea                 Hosea
# 17  4451                              Book of Jonah                 Jonah
# 18  4452                              Book of Micah                 Micah
# 19  4454                             Book of Haggai                Haggai
# 20  6020                                      Crash         J. G. Ballard
# 21  6628                           Children of Dune         Frank Herbert
# 22  6629                    Candide, ou l'Optimisme              Voltaire
# 23  6630                          Chapterhouse Dune         Frank Herbert
# 24  6921                                   Carmilla      Sheridan Le Fanu
# 25  7817                      The Cider House Rules           John Irving
# 26  7923                                    Dracula           Bram Stoker
# 27  8237                                Don Quixote   Miguel de Cervantes
# 28  8547                                Deuteronomy                   NaN
# 29  8567                               Dune Messiah         Frank Herbert
#
#    publish_year                                            summary  \
# 0          1945   Old Major, the old boar on the Manor Farm, ca...
# 1          1962   Alex, a teenager living in near-future Englan...
# 2          1947   The text of The Plague is divided into five p...
# 3           NaN   The argument of the Enquiry proceeds by a ser...
# 4           NaN   The novel posits that space around the Milky ...
# 5          1929   The book tells the story of Paul Bäumer, a Ge...
# 6          1968   Ged is a young boy on Gont, one of the larger...
# 7           NaN   The story is set in an imaginary American tow...
# 8          1996   Living on Mars, Deckard is acting as a consul...
# 9          1995   Beginning several months after the events in ...
# 10            0   (Chapter 1 is the first of three important mo...
# 11            0   For the Bible text, see Bible Gateway (opens ...
# 12            0   God orders Moses, in the wilderness of Sinai,...
# 13            0   During the time of the Judges when there was ...
# 14            0   Ahasuerus, ruler of a massive Persian empire,...
# 15            0   The book of Job tells the story of an extreme...
# 16            0   First, Hosea was directed by God to marry a p...
# 17            0   The plot centers on a conflict between Jonah ...
# 18            0   * The Heading (1:1): As is typical of prophet...
# 19            0   Haggai's message is filled with an urgency fo...
# 20         1973   The story is told through the eyes of narrato...
# 21         1976   Nine years after Emperor Paul Muad'dib walked...
# 22         1759   Candide contains thirty episodic chapters, wh...
# 23         1985   The situation is desperate for the Bene Gesse...
# 24         1872   The story is presented by Le Fanu as part of ...
# 25         1985   Homer Wells grows up in an orphanage where he...
# 26         1897   The novel is told in epistolary format, as a ...
# 27         1605   The First Sally Alonso Quijano, the protagoni...
# 28          NaN   (The following "literary" outline of Deuteron...
# 29         1969   Twelve years after the events described in Du...
#
#                                           genre_names
# 0   [Roman  clef, Satire, Children's literature, S...
# 1   [Science Fiction, Novella, Speculative fiction...
# 2   [Existentialism, Fiction, Absurdist fiction, N...
# 3                                                 NaN
# 4   [Hard science fiction, Science Fiction, Specul...
# 5                            [War novel, Roman  clef]
# 6   [Children's literature, Fantasy, Speculative f...
# 7                                                 NaN
# 8              [Science Fiction, Speculative fiction]
# 9              [Science Fiction, Speculative fiction]
# 10                                   [Religious text]
# 11                                   [Religious text]
# 12                                   [Religious text]
# 13                                   [Religious text]
# 14                                   [Religious text]
# 15                                   [Religious text]
# 16                                   [Religious text]
# 17                                   [Religious text]
# 18                                   [Religious text]
# 19                                   [Religious text]
# 20              [Speculative fiction, Fiction, Novel]
# 21  [Science Fiction, Speculative fiction, Childre...
# 22          [Satire, Bildungsroman, Picaresque novel]
# 23  [Science Fiction, Speculative fiction, Childre...
# 24                                   [Gothic fiction]
# 25                                          [Fiction]
# 26  [Science Fiction, Speculative fiction, Horror,...
# 27  [Parody, Children's literature, Psychological ...
# 28                                                NaN
# 29  [Science Fiction, Speculative fiction, Childre...

# %%
print(df.isna().sum())
# Out:
# id                 0
# name               0
# author          2372
# publish_year    5598
# summary            0
# genre_names     3708
# dtype: int64

# %%
x =df.groupby(['author']).count()
x
# Out:
#                         id  name  publish_year  summary  genre_names
# author
# 'Asta Bowen              1     1             1        1            1
# A. A. Attanasio          2     2             2        2            2
# A. A. Milne              2     2             2        2            2
# A. E. W. Mason           2     2             2        2            2
# A. E. van Vogt          11    11            10       11           11
# ...                     ..   ...           ...      ...          ...
# Élisabeth Vonarburg      1     1             1        1            1
# Émile Gaboriau           1     1             0        1            1
# Émile Zola              16    16            15       16           15
# Ólafur Jóhann Ólafsson   4     4             0        4            0
# ʻAlāʼ Aswānī             1     1             0        1            1
#
# [4725 rows x 5 columns]

# %%
y = df[df['author'] == 'A. E. van Vogt']
y
# Out:
#              id                            name          author publish_year  \
# 1248     544984             The World of Null-A  A. E. van Vogt         1948
# 1392     623749  The Voyage of the Space Beagle  A. E. van Vogt         1950
# 1819     911169                            Slan  A. E. van Vogt         1946
# 2262    1234613       The Weapon Shops of Isher  A. E. van Vogt         1951
# 9315    9917470            Children of Tomorrow  A. E. van Vogt         1970
# 10297  12216391                      Rogue Ship  A. E. van Vogt         1965
# 11814  16277049               The Book of Ptath  A. E. van Vogt         1947
# 12090  17076520              Empire of the Atom  A. E. van Vogt         1957
# 12579  18558694                      The Silkie  A. E. van Vogt          NaN
# 13722  21829284              The Universe Maker  A. E. van Vogt         1953
# 14424  24107193              The Wizard of Linn  A. E. van Vogt         1962
#
#                                                  summary  \
# 1248    Gilbert Gosseyn, a man living in an apparent ...
# 1392    The main protagonist of the novel is Dr. Elli...
# 1819    Slans are evolved humans, named after their a...
# 2262    The Weapon Shops of Isher and its sequel The ...
# 9315    Commander John Lane returns from a ten year m...
# 10297   Rogue Ship is a standalone novel in a form of...
# 11814   The novel concerns a tank-battle casualty rei...
# 12090   The novel concerns adventures of a mutant gen...
# 12579   The novel has four sections, each consisting ...
# 13722   Morton Cargill, Korean War soldier, accidenta...
# 14424   A war between humanity and an extraterrestria...
#
#                                              genre_names
# 1248       [Science Fiction, Speculative fiction, Novel]
# 1392              [Science Fiction, Speculative fiction]
# 1819   [Science Fiction, Speculative fiction, Fantasy...
# 2262   [Science Fiction, Speculative fiction, Fiction...
# 9315              [Science Fiction, Speculative fiction]
# 10297             [Science Fiction, Speculative fiction]
# 11814                                  [Science Fiction]
# 12090             [Science Fiction, Speculative fiction]
# 12579             [Science Fiction, Speculative fiction]
# 13722                           [Science Fiction, Novel]
# 14424                                  [Science Fiction]

# %%
def fill_missing_years(df):
    #in rows with missing 'publish_year'
    for index, row in df[df['publish_year'].isnull()].iterrows():
        author = row['author']
        #the first non-null publish_year for the same author
        matching_year = df.loc[(df['author'] == author) & (df['publish_year'].notnull()), 'publish_year']
        
        if not matching_year.empty:
            # Fill the missing publish_year with the found year
            df.at[index, 'publish_year'] = matching_year.iloc[0]

fill_missing_years(df)

# %%
z = df[df['author'] == 'A. E. van Vogt']
z
# Out:
#              id                            name          author publish_year  \
# 1248     544984             The World of Null-A  A. E. van Vogt         1948
# 1392     623749  The Voyage of the Space Beagle  A. E. van Vogt         1950
# 1819     911169                            Slan  A. E. van Vogt         1946
# 2262    1234613       The Weapon Shops of Isher  A. E. van Vogt         1951
# 9315    9917470            Children of Tomorrow  A. E. van Vogt         1970
# 10297  12216391                      Rogue Ship  A. E. van Vogt         1965
# 11814  16277049               The Book of Ptath  A. E. van Vogt         1947
# 12090  17076520              Empire of the Atom  A. E. van Vogt         1957
# 12579  18558694                      The Silkie  A. E. van Vogt         1948
# 13722  21829284              The Universe Maker  A. E. van Vogt         1953
# 14424  24107193              The Wizard of Linn  A. E. van Vogt         1962
#
#                                                  summary  \
# 1248    Gilbert Gosseyn, a man living in an apparent ...
# 1392    The main protagonist of the novel is Dr. Elli...
# 1819    Slans are evolved humans, named after their a...
# 2262    The Weapon Shops of Isher and its sequel The ...
# 9315    Commander John Lane returns from a ten year m...
# 10297   Rogue Ship is a standalone novel in a form of...
# 11814   The novel concerns a tank-battle casualty rei...
# 12090   The novel concerns adventures of a mutant gen...
# 12579   The novel has four sections, each consisting ...
# 13722   Morton Cargill, Korean War soldier, accidenta...
# 14424   A war between humanity and an extraterrestria...
#
#                                              genre_names
# 1248       [Science Fiction, Speculative fiction, Novel]
# 1392              [Science Fiction, Speculative fiction]
# 1819   [Science Fiction, Speculative fiction, Fantasy...
# 2262   [Science Fiction, Speculative fiction, Fiction...
# 9315              [Science Fiction, Speculative fiction]
# 10297             [Science Fiction, Speculative fiction]
# 11814                                  [Science Fiction]
# 12090             [Science Fiction, Speculative fiction]
# 12579             [Science Fiction, Speculative fiction]
# 13722                           [Science Fiction, Novel]
# 14424                                  [Science Fiction]

# %% [markdown]
# #### Genres:

# %%
x =df.groupby(['author']).count()
x
# Out:
#                         id  name  publish_year  summary  genre_names
# author
# 'Asta Bowen              1     1             1        1            1
# A. A. Attanasio          2     2             2        2            2
# A. A. Milne              2     2             2        2            2
# A. E. W. Mason           2     2             2        2            2
# A. E. van Vogt          11    11            11       11           11
# ...                     ..   ...           ...      ...          ...
# Élisabeth Vonarburg      1     1             1        1            1
# Émile Gaboriau           1     1             0        1            1
# Émile Zola              16    16            16       16           15
# Ólafur Jóhann Ólafsson   4     4             0        4            0
# ʻAlāʼ Aswānī             1     1             0        1            1
#
# [4725 rows x 5 columns]

# %%
q =  df[df['author'] == 'Émile Zola']
q
# Out:
#              id                          name      author publish_year  \
# 428      155591         La Fortune des Rougon  Émile Zola         1871
# 429      155592  Son Excellence Eugène Rougon  Émile Zola         1876
# 430      155594                      La Curée  Émile Zola         1871
# 431      155597                      L'Argent  Émile Zola         1891
# 611      213406          Au Bonheur des Dames  Émile Zola         1883
# 926      360837                      Germinal  Émile Zola         1885
# 1151     490935                      Assomoir  Émile Zola         1877
# 1653     814647                          Nana  Émile Zola         1880
# 2347    1285975                Thérèse Raquin  Émile Zola         1867
# 8264    7930528              La Joie de vivre  Émile Zola         1884
# 8450    8367809              Une Page d'amour  Émile Zola         1878
# 8543    8563808                       Le Rêve  Émile Zola         1888
# 9213    9687542                   Pot-Bouille  Émile Zola         1882
# 9744   10959260             Le Docteur Pascal  Émile Zola         1893
# 12465  18135724     Les Mystères de Marseille  Émile Zola         1895
# 15570  29154764                  L'Inondation  Émile Zola         1871
#
#                                                  summary  \
# 428     After a stirring opening on the eve of the co...
# 429     The novel opens in 1857 with Rougon's career ...
# 430     The book opens with scenes of astonishing opu...
# 431     The novel takes place in 1864-1869, beginning...
# 611     The events of Au Bonheur des Dames cover appr...
# 926     The novel's central character is Étienne Lant...
# 1151    The novel is essentially the story of Gervais...
# 1653    Nana tells the story of Nana Coupeau's rise f...
# 2347    Thérèse Raquin is the daughter of a French ca...
# 8264    The novel opens in 1863 and covers about 10 y...
# 8450    The story takes place in 1854-1855. When the ...
# 8543    Le rêve is a simple tale of the orphan Angéli...
# 9213    Pot-Bouille recounts the activities of the re...
# 9744    Pascal, a physician in Plassans for 30 years,...
# 12465   Les Mystères de Marseille recounts the love o...
# 15570   On a beautiful May day, the Garonne floods, w...
#
#                              genre_names
# 428                                  NaN
# 429                              [Novel]
# 430                              [Novel]
# 431                              [Novel]
# 611                              [Novel]
# 926                              [Novel]
# 1151                             [Novel]
# 1653                             [Novel]
# 2347   [Psychology, Psychological novel]
# 8264                             [Novel]
# 8450                             [Novel]
# 8543                             [Novel]
# 9213                             [Novel]
# 9744                             [Novel]
# 12465              [Psychological novel]
# 15570                      [Short story]

# %%
'''def fill_missing_genres(df):
    #in rows with missing 'publish_year'
    for index, row in df[df['genre_names'].isnull()].iterrows():
        author = row['author']
        #the first non-null publish_year for the same author
        matching_year = df.loc[(df['author'] == author) & (df['genre_names'].notnull()), 'genre_names']
        
        if not matching_year.empty:
            # Fill the missing publish_year with the found year
            df.at[index, 'genre_names'] = matching_year.iloc[0]

fill_missing_genres(df)'''
# Out:
# "def fill_missing_genres(df):\n    #in rows with missing 'publish_year'\n    for index, row in df[df['genre_names'].isnull()].iterrows():\n        author = row['author']\n        #the first non-null publish_year for the same author\n        matching_year = df.loc[(df['author'] == author) & (df['genre_names'].notnull()), 'genre_names']\n        \n        if not matching_year.empty:\n            # Fill the missing publish_year with the found year\n            df.at[index, 'genre_names'] = matching_year.iloc[0]\n\nfill_missing_genres(df)"

# %%
# Replace empty lists with NaN
df['genre_names'] = df['genre_names'].apply(lambda x: np.nan if isinstance(x, list) and len(x) == 0 else x)

def fill_missing_genres(df):
    for index, row in df[df['genre_names'].isnull()].iterrows():
        author = row['author']
        # Get all non-null genre_names for the same author
        matching_genres = df.loc[df['author'] == author, 'genre_names'].dropna()
        
        if not matching_genres.empty:
            # Combine all genres into a list
            combined_genres = [genre for sublist in matching_genres for genre in sublist]
            # Remove duplicates by converting to a set and back to a list
            df.at[index, 'genre_names'] = list(set(combined_genres))

# Fill missing genres
fill_missing_genres(df)

# %%
df
# Out:
#              id                                               name  \
# 0           620                                        Animal Farm
# 1           843                                 A Clockwork Orange
# 2           986                                         The Plague
# 3          1756          An Enquiry Concerning Human Understanding
# 4          2080                               A Fire Upon the Deep
# ...         ...                                                ...
# 16554  36934824                                     Under Wildwood
# 16555  37054020                                  Transfer of Power
# 16556  37122323                                            Decoded
# 16557  37132319  America Again: Re-becoming The Greatness We Ne...
# 16558  37159503                                          Poor Folk
#
#                    author publish_year  \
# 0           George Orwell         1945
# 1         Anthony Burgess         1962
# 2            Albert Camus         1947
# 3              David Hume          NaN
# 4            Vernor Vinge         1981
# ...                   ...          ...
# 16554         Colin Meloy         2012
# 16555         Vince Flynn         2000
# 16556               Jay-Z         2010
# 16557     Stephen Colbert         2012
# 16558  Fyodor Dostoyevsky         1846
#
#                                                  summary  \
# 0       Old Major, the old boar on the Manor Farm, ca...
# 1       Alex, a teenager living in near-future Englan...
# 2       The text of The Plague is divided into five p...
# 3       The argument of the Enquiry proceeds by a ser...
# 4       The novel posits that space around the Milky ...
# ...                                                  ...
# 16554   Prue McKeel, having rescued her brother from ...
# 16555   The reader first meets Rapp while he is doing...
# 16556   The book follows very rough chronological ord...
# 16557   Colbert addresses topics including Wall Stree...
# 16558   Makar Devushkin and Varvara Dobroselova are s...
#
#                                              genre_names
# 0      [Roman  clef, Satire, Children's literature, S...
# 1      [Science Fiction, Novella, Speculative fiction...
# 2      [Existentialism, Fiction, Absurdist fiction, N...
# 3                                                    NaN
# 4      [Hard science fiction, Science Fiction, Specul...
# ...                                                  ...
# 16554                                                NaN
# 16555                                [Thriller, Fiction]
# 16556                                    [Autobiography]
# 16557                                                NaN
# 16558            [Epistolary novel, Speculative fiction]
#
# [16559 rows x 6 columns]

# %%
df.shape
# Out:
# (16559, 6)

# %%
p =  df[df['author'] == 'Émile Zola']
p
# Out:
#              id                          name      author publish_year  \
# 428      155591         La Fortune des Rougon  Émile Zola         1871
# 429      155592  Son Excellence Eugène Rougon  Émile Zola         1876
# 430      155594                      La Curée  Émile Zola         1871
# 431      155597                      L'Argent  Émile Zola         1891
# 611      213406          Au Bonheur des Dames  Émile Zola         1883
# 926      360837                      Germinal  Émile Zola         1885
# 1151     490935                      Assomoir  Émile Zola         1877
# 1653     814647                          Nana  Émile Zola         1880
# 2347    1285975                Thérèse Raquin  Émile Zola         1867
# 8264    7930528              La Joie de vivre  Émile Zola         1884
# 8450    8367809              Une Page d'amour  Émile Zola         1878
# 8543    8563808                       Le Rêve  Émile Zola         1888
# 9213    9687542                   Pot-Bouille  Émile Zola         1882
# 9744   10959260             Le Docteur Pascal  Émile Zola         1893
# 12465  18135724     Les Mystères de Marseille  Émile Zola         1895
# 15570  29154764                  L'Inondation  Émile Zola         1871
#
#                                                  summary  \
# 428     After a stirring opening on the eve of the co...
# 429     The novel opens in 1857 with Rougon's career ...
# 430     The book opens with scenes of astonishing opu...
# 431     The novel takes place in 1864-1869, beginning...
# 611     The events of Au Bonheur des Dames cover appr...
# 926     The novel's central character is Étienne Lant...
# 1151    The novel is essentially the story of Gervais...
# 1653    Nana tells the story of Nana Coupeau's rise f...
# 2347    Thérèse Raquin is the daughter of a French ca...
# 8264    The novel opens in 1863 and covers about 10 y...
# 8450    The story takes place in 1854-1855. When the ...
# 8543    Le rêve is a simple tale of the orphan Angéli...
# 9213    Pot-Bouille recounts the activities of the re...
# 9744    Pascal, a physician in Plassans for 30 years,...
# 12465   Les Mystères de Marseille recounts the love o...
# 15570   On a beautiful May day, the Garonne floods, w...
#
#                                              genre_names
# 428    [Psychological novel, Novel, Short story, Psyc...
# 429                                              [Novel]
# 430                                              [Novel]
# 431                                              [Novel]
# 611                                              [Novel]
# 926                                              [Novel]
# 1151                                             [Novel]
# 1653                                             [Novel]
# 2347                   [Psychology, Psychological novel]
# 8264                                             [Novel]
# 8450                                             [Novel]
# 8543                                             [Novel]
# 9213                                             [Novel]
# 9744                                             [Novel]
# 12465                              [Psychological novel]
# 15570                                      [Short story]

# %%
print(df.isna().sum())
# Out:
# id                 0
# name               0
# author          2372
# publish_year    3247
# summary            0
# genre_names     2748
# dtype: int64

# %%
nan_count = df[df[['genre_names', 'publish_year', 'author']].isnull().all(axis=1)].shape[0]
nan_count
# Out:
# 1320

# %%
df = df.sort_values(by=['id'] , ascending=True)
df.head(30)
# Out:
#       id                                       name                author  \
# 0    620                                Animal Farm         George Orwell
# 1    843                         A Clockwork Orange       Anthony Burgess
# 2    986                                 The Plague          Albert Camus
# 3   1756  An Enquiry Concerning Human Understanding            David Hume
# 4   2080                       A Fire Upon the Deep          Vernor Vinge
# 5   2152             All Quiet on the Western Front  Erich Maria Remarque
# 6   2890                       A Wizard of Earthsea     Ursula K. Le Guin
# 7   2950                         Anyone Can Whistle       Arthur Laurents
# 8   4081            Blade Runner 3: Replicant Night           K. W. Jeter
# 9   4082          Blade Runner 2: The Edge of Human           K. W. Jeter
# 10  4331                             Book of Joshua                Joshua
# 11  4332                               Book of Ezra                  Ezra
# 12  4376                            Book of Numbers               Numbers
# 13  4381                               Book of Ruth                  Ruth
# 14  4382                             Book of Esther                Esther
# 15  4386                                Book of Job                   Job
# 16  4449                              Book of Hosea                 Hosea
# 17  4451                              Book of Jonah                 Jonah
# 18  4452                              Book of Micah                 Micah
# 19  4454                             Book of Haggai                Haggai
# 20  6020                                      Crash         J. G. Ballard
# 21  6628                           Children of Dune         Frank Herbert
# 22  6629                    Candide, ou l'Optimisme              Voltaire
# 23  6630                          Chapterhouse Dune         Frank Herbert
# 24  6921                                   Carmilla      Sheridan Le Fanu
# 25  7817                      The Cider House Rules           John Irving
# 26  7923                                    Dracula           Bram Stoker
# 27  8237                                Don Quixote   Miguel de Cervantes
# 28  8547                                Deuteronomy                   NaN
# 29  8567                               Dune Messiah         Frank Herbert
#
#    publish_year                                            summary  \
# 0          1945   Old Major, the old boar on the Manor Farm, ca...
# 1          1962   Alex, a teenager living in near-future Englan...
# 2          1947   The text of The Plague is divided into five p...
# 3           NaN   The argument of the Enquiry proceeds by a ser...
# 4          1981   The novel posits that space around the Milky ...
# 5          1929   The book tells the story of Paul Bäumer, a Ge...
# 6          1968   Ged is a young boy on Gont, one of the larger...
# 7           NaN   The story is set in an imaginary American tow...
# 8          1996   Living on Mars, Deckard is acting as a consul...
# 9          1995   Beginning several months after the events in ...
# 10            0   (Chapter 1 is the first of three important mo...
# 11            0   For the Bible text, see Bible Gateway (opens ...
# 12            0   God orders Moses, in the wilderness of Sinai,...
# 13            0   During the time of the Judges when there was ...
# 14            0   Ahasuerus, ruler of a massive Persian empire,...
# 15            0   The book of Job tells the story of an extreme...
# 16            0   First, Hosea was directed by God to marry a p...
# 17            0   The plot centers on a conflict between Jonah ...
# 18            0   * The Heading (1:1): As is typical of prophet...
# 19            0   Haggai's message is filled with an urgency fo...
# 20         1973   The story is told through the eyes of narrato...
# 21         1976   Nine years after Emperor Paul Muad'dib walked...
# 22         1759   Candide contains thirty episodic chapters, wh...
# 23         1985   The situation is desperate for the Bene Gesse...
# 24         1872   The story is presented by Le Fanu as part of ...
# 25         1985   Homer Wells grows up in an orphanage where he...
# 26         1897   The novel is told in epistolary format, as a ...
# 27         1605   The First Sally Alonso Quijano, the protagoni...
# 28          NaN   (The following "literary" outline of Deuteron...
# 29         1969   Twelve years after the events described in Du...
#
#                                           genre_names
# 0   [Roman  clef, Satire, Children's literature, S...
# 1   [Science Fiction, Novella, Speculative fiction...
# 2   [Existentialism, Fiction, Absurdist fiction, N...
# 3                                                 NaN
# 4   [Hard science fiction, Science Fiction, Specul...
# 5                            [War novel, Roman  clef]
# 6   [Children's literature, Fantasy, Speculative f...
# 7                                                 NaN
# 8              [Science Fiction, Speculative fiction]
# 9              [Science Fiction, Speculative fiction]
# 10                                   [Religious text]
# 11                                   [Religious text]
# 12                                   [Religious text]
# 13                                   [Religious text]
# 14                                   [Religious text]
# 15                                   [Religious text]
# 16                                   [Religious text]
# 17                                   [Religious text]
# 18                                   [Religious text]
# 19                                   [Religious text]
# 20              [Speculative fiction, Fiction, Novel]
# 21  [Science Fiction, Speculative fiction, Childre...
# 22          [Satire, Bildungsroman, Picaresque novel]
# 23  [Science Fiction, Speculative fiction, Childre...
# 24                                   [Gothic fiction]
# 25                                          [Fiction]
# 26  [Science Fiction, Speculative fiction, Horror,...
# 27  [Parody, Children's literature, Psychological ...
# 28                                                NaN
# 29  [Science Fiction, Speculative fiction, Childre...

# %%
df.to_csv('data.csv', index=False)
